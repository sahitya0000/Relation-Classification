# %%
import numpy as np
np.random.seed(1337) 
import os 
from keras import backend as K
from keras.models import Model, Sequential
from keras.layers import Concatenate, Embedding, Input, Dropout, Dense, Activation, Bidirectional, GlobalMaxPooling1D
from keras.layers import Convolution1D, LSTM, GRU, CuDNNGRU, CuDNNLSTM, Permute, Lambda, Flatten
from keras import optimizers
from keras.engine.topology import Layer
import tensorflow as tf
from keras import regularizers
from keras.models import load_model
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Data and Scorer path settings 

data_npy_path = './data/data_all.npy'
scorer_perl_script = "./corpus/SemEval2010_task8_scorer-v1.2/semeval2010_task8_scorer-v1.2.pl"
train_answer_key = "./files/train_answer_keys.txt"
val_answer_key = "./files/val_answer_keys.txt"
test_answer_key = "./files/test_answer_keys.txt"

proposed_ans = "./model/proposed_ans.txt"
scorer_output = "./model/scorer_output.txt"

perl_exe_path = "C:/Dwimperl/perl/bin/perl.exe" # for windows

# %%
# Data Loading

train_set, val_set, test_set, embedding, label_to_int, int_to_label = np.load(data_npy_path)

train_x, train_y = train_set
val_x, val_y = val_set
test_x, test_y = test_set

train_x_copy = train_x
train_y_copy = train_y

max_sentence_len = train_x.shape[1]
n_out = len(label_to_int)

print("train_x.shape", train_x.shape)
print("train_y.shape", train_y.shape)
print("val_x.shape", val_x.shape)
print("val_y.shape", val_y.shape)
print("test_x.shape", test_x.shape)
print("test_y.shape", test_y.shape)
print("embedding.shape", embedding.shape)
print("len(label_to_int)", len(label_to_int))
print("len(int_to_label)", len(int_to_label))
print("max_sentence_len", max_sentence_len)
print("n_out", n_out)
print()
# Out:
# train_x.shape (7208, 101)
# train_y.shape (7208,)
# val_x.shape (792, 101)
# val_y.shape (792,)
# test_x.shape (2717, 101)
# test_y.shape (2717,)
# embedding.shape (25656, 300)
# len(label_to_int) 19
# len(int_to_label) 19
# max_sentence_len 101
# n_out 19

# %%
def get_mask_entities(x):
    ''' 1 for entity words, 0 otherwise '''
    
    ret = np.zeros_like(x)
    #print("get_mask shape", ret.shape)
    # e1s 2409
    # e1e 2408
    # e2s 2411
    # e2e 2410
    for i in range(x.shape[0]): 
        e1 = [0, 0]
        e2 = [0, 0]
        for j in range(x.shape[1]):
            if x[i][j] == 2409:
                e1[0] = j
            elif x[i][j] == 2408: 
                e1[1] = j
            elif x[i][j] == 2411: 
                e2[0] = j
            elif x[i][j] == 2410: 
                e2[1] = j
                break
        for j in range(e1[0]+1, e1[1]): 
            ret[i][j] = 1
        for j in range(e2[0]+1, e2[1]): 
            ret[i][j] = 1
        #print(ret[i][e1[0]:e1[1]+1], x[i][e1[0]:e1[1]+1])
    
    return ret

# %%
train_x_mask = get_mask_entities(train_x)
train_x_mask_copy = train_x_mask
val_x_mask = get_mask_entities(val_x)
test_x_mask = get_mask_entities(test_x)

print("train_x_mask.shape", train_x_mask.shape)
print("train_x_mask_copy.shape", train_x_mask_copy.shape)
print("val_x_mask.shape", val_x_mask.shape)
print("test_x_mask.shape", test_x_mask.shape)
# Out:
# train_x_mask.shape (7208, 101)
# train_x_mask_copy.shape (7208, 101)
# val_x_mask.shape (792, 101)
# test_x_mask.shape (2717, 101)

# %%
# Parameters 

units = 64
batch_size = 128 #10
dropout_emb = 0.64
dropout_model = 0.32
dropout_pen = 0.32
l2_val = 0.00001
learning_rate = 1.0
activation_fn = 'tanh'
nb_epoch = 256
adadelta = optimizers.Adadelta(lr=learning_rate, decay=0.0)
save_model = True
es_epoch_stop = 20

print("units", units)
print("batch_size", batch_size)
print("dropout_emb", dropout_emb)
print("dropout_model", dropout_model)
print("dropout_pen", dropout_pen)
print("l2_val", l2_val)
print("learning_rate", learning_rate)
print("activation_fn", activation_fn)
print("nb_epoch", nb_epoch)
print("adadelta", adadelta)
print("save_model", save_model)
print("es_epoch_stop", es_epoch_stop)
print()

embeddings_reg = regularizers.l2(l2_val)
kernel_reg = regularizers.l2(l2_val)
recurrent_reg = regularizers.l2(l2_val)
# Out:
# units 64
# batch_size 128
# dropout_emb 0.64
# dropout_model 0.32
# dropout_pen 0.32
# l2_val 1e-05
# learning_rate 1.0
# activation_fn tanh
# nb_epoch 256
# adadelta <keras.optimizers.Adadelta object at 0x000001C3D499D470>
# save_model True
# es_epoch_stop 20

# %%
# class AttnLayer(Layer):
#     # Attention-Based Bidirectional Long Short-Term Memory Networks for Relation Classification
#     # input: ?, 102, 200
    
#     def __init__(self, **kwargs):
#         super(AttnLayer, self).__init__(**kwargs)
    
#     def build(self, input_shape):
#         # Create a trainable weight variable for this layer.
#         self.W = self.add_weight(name='W', shape=(input_shape[-1], 1), initializer='glorot_uniform', trainable=True, regularizer = kernel_reg)        
#         super(AttnLayer, self).build(input_shape)  # Be sure to call this somewhere!

#     def call(self, x):
#         M = K.tanh(x) # ? 101 600
#         alpha_bar = tf.matmul(M, self.W)  # ? 101 1
#         alpha = K.permute_dimensions(alpha_bar, pattern=[0, 2, 1]) # ? 1 101

#         alpha = K.softmax(alpha) # ? 1 101
#         r_bar = tf.matmul(alpha, M) # ? 1 600
#         r = K.squeeze(r_bar, axis=-2) # ? 600
#         r = K.tanh(r)
#         return r
    
#     def compute_output_shape(self, input_shape):
#         return (input_shape[0], input_shape[-1])
    

    

# class MaskSumPoolingLayer(Layer):
#     # input_shape [(None, 101, 600), (None, 101)]
#     # input:  (?, 101, 600) (?, 101)
#     # output: (?, 600)
    
#     def __init__(self, **kwargs):
#         super(MaskSumPoolingLayer, self).__init__(**kwargs)
    
#     def build(self, input_shape):
#         super(MaskSumPoolingLayer, self).build(input_shape)  # Be sure to call this somewhere!

#     def call(self, x):
#         x_1_float32 = K.cast(x[1], dtype='float32')
#         #print("x_1_float32", x_1_float32)
#         x_0 = K.permute_dimensions(x[0], pattern=[2, 0, 1])
#         #print("x_0", x_0)
#         x_0 = tf.multiply(x_0, x_1_float32)
#         #print("x_0", x_0)
#         x_0 = K.permute_dimensions(x_0, pattern=[1, 2, 0])
#         #print("x_0", x_0)
#         x_0 = K.sum(x_0, axis=-2)
#         #print("x_0", x_0)
#         return x_0
    
#     def compute_output_shape(self, input_shape):
#         # input_shape [(None, 101, 600), (None, 101)]
#         return (input_shape[0][0], input_shape[0][-1])

# %%
class MaskMaxPoolingLayer(Layer):
    # input_shape [(None, 101, 600), (None, 101)]
    # input:  (?, 101, 600) (?, 101)
    # output: (?, 600)
    
    def __init__(self, **kwargs):
        super(MaskMaxPoolingLayer, self).__init__(**kwargs)
    
    def build(self, input_shape):
        super(MaskMaxPoolingLayer, self).build(input_shape)  # Be sure to call this somewhere!

    def call(self, x):
        x_1_float32 = K.cast(x[1], dtype='float32')
        #print("x_1_float32", x_1_float32)
        x_0 = K.permute_dimensions(x[0], pattern=[2, 0, 1])
        #print("x_0", x_0)
        x_0 = tf.multiply(x_0, x_1_float32)
        #print("x_0", x_0)
        x_0 = K.permute_dimensions(x_0, pattern=[1, 2, 0])
        #print("x_0", x_0)
        x_0 = K.max(x_0, axis=-2)
        #print("x_0", x_0)
        return x_0
    
    def compute_output_shape(self, input_shape):
        # input_shape [(None, 101, 600), (None, 101)]
        return (input_shape[0][0], input_shape[0][-1])

# %%
# Model

words_input = Input(shape=(max_sentence_len,), dtype='int32', name='words_input')
words_input_mask = Input(shape=(max_sentence_len,), dtype='int32', name='words_input_mask')

words = Embedding(embedding.shape[0], embedding.shape[1], weights=[embedding], trainable=True, embeddings_regularizer=embeddings_reg, name="words_Embedding")(words_input)
words = Dropout(dropout_emb)(words)

output = Convolution1D(filters=256, kernel_size=3, activation=activation_fn, padding='same', strides=1, kernel_regularizer=kernel_reg)(words)
output = Dropout(dropout_model)(output)

output = Bidirectional( CuDNNGRU(units, return_sequences=True, recurrent_regularizer=recurrent_reg), merge_mode='concat') (output)
output_h = Activation('tanh') (output)

output1 = GlobalMaxPooling1D()(output_h) 
output2 = MaskMaxPoolingLayer()([output_h, words_input_mask]) 

output = Dense(1, kernel_regularizer=kernel_reg)(output_h)
output = Permute((2, 1))(output)
output = Activation('softmax', name="attn_softmax")(output)
output = Lambda(lambda x: tf.matmul(x[0], x[1])) ([output, output_h])
output3 = Flatten() (output)

output = Concatenate()([output1, output2, output3])
output = Dropout(dropout_pen)(output)

output = Dense(300, kernel_regularizer=kernel_reg, activation='relu')(output)
output = Dense(n_out, kernel_regularizer=kernel_reg)(output)
output = Activation('softmax')(output)

model = Model(inputs=[words_input, words_input_mask], outputs=[output])
model.compile(loss='sparse_categorical_crossentropy', optimizer=adadelta, metrics=['accuracy'])
model.summary(line_length=120)
# Out:
# ________________________________________________________________________________________________________________________
# Layer (type)                           Output Shape               Param #       Connected to
# ========================================================================================================================
# words_input (InputLayer)               (None, 101)                0
# ________________________________________________________________________________________________________________________
# words_Embedding (Embedding)            (None, 101, 300)           7696800       words_input[0][0]
# ________________________________________________________________________________________________________________________
# dropout_1 (Dropout)                    (None, 101, 300)           0             words_Embedding[0][0]
# ________________________________________________________________________________________________________________________
# conv1d_1 (Conv1D)                      (None, 101, 256)           230656        dropout_1[0][0]
# ________________________________________________________________________________________________________________________
# dropout_2 (Dropout)                    (None, 101, 256)           0             conv1d_1[0][0]
# ________________________________________________________________________________________________________________________
# bidirectional_1 (Bidirectional)        (None, 101, 128)           123648        dropout_2[0][0]
# ________________________________________________________________________________________________________________________
# activation_1 (Activation)              (None, 101, 128)           0             bidirectional_1[0][0]
# ________________________________________________________________________________________________________________________
# dense_1 (Dense)                        (None, 101, 1)             129           activation_1[0][0]
# ________________________________________________________________________________________________________________________
# permute_1 (Permute)                    (None, 1, 101)             0             dense_1[0][0]
# ________________________________________________________________________________________________________________________
# attn_softmax (Activation)              (None, 1, 101)             0             permute_1[0][0]
# ________________________________________________________________________________________________________________________
# words_input_mask (InputLayer)          (None, 101)                0
# ________________________________________________________________________________________________________________________
# lambda_1 (Lambda)                      (None, 1, 128)             0             attn_softmax[0][0]
#                                                                                 activation_1[0][0]
# ________________________________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalMaxPooli (None, 128)                0             activation_1[0][0]
# ________________________________________________________________________________________________________________________
# mask_max_pooling_layer_1 (MaskMaxPooli (None, 128)                0             activation_1[0][0]
#                                                                                 words_input_mask[0][0]
# ________________________________________________________________________________________________________________________
# flatten_1 (Flatten)                    (None, 128)                0             lambda_1[0][0]
# ________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)            (None, 384)                0             global_max_pooling1d_1[0][0]
#                                                                                 mask_max_pooling_layer_1[0][0]
#                                                                                 flatten_1[0][0]
# ________________________________________________________________________________________________________________________
# dropout_3 (Dropout)                    (None, 384)                0             concatenate_1[0][0]
# ________________________________________________________________________________________________________________________
# dense_2 (Dense)                        (None, 300)                115500        dropout_3[0][0]
# ________________________________________________________________________________________________________________________
# dense_3 (Dense)                        (None, 19)                 5719          dense_2[0][0]
# ________________________________________________________________________________________________________________________
# activation_2 (Activation)              (None, 19)                 0             dense_3[0][0]
# ========================================================================================================================
# Total params: 8,172,452
# Trainable params: 8,172,452
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________

# %%
# Evaluation functions 

def get_precision(test_y_pred, test_y, label): 
    label_count = 0
    label_count_correct = 0
    
    for i in range(len(test_y_pred)):
        if test_y_pred[i] == label: 
            label_count += 1 
            if test_y_pred[i] == test_y[i]: 
                label_count_correct += 1
    
    if label_count_correct == 0: 
        return 0.0
    else: 
        ret = float(label_count_correct) / float(label_count)
        return ret
        

def get_macro_f1(test_y_pred, test_y, n_out):
    f1_sum = 0
    f1_count = 0
    for label in range(1, n_out):        
        prec = get_precision(test_y_pred, test_y, label)
        recall = get_precision(test_y, test_y_pred, label)
        f1 = 0 if float(prec+recall)==float(0) else float(2*prec*recall/float(prec+recall))
        f1_sum += f1
        f1_count += 1
    macro_f1 = float(f1_sum) / float(f1_count)    
    return macro_f1
    

def get_accuracy(test_y_pred, test_y):
    acc =  float(np.sum(test_y_pred == test_y)) / float(len(test_y))
    return acc
    
    
def predict_classes(prediction):
    return prediction.argmax(axis=-1)


def get_PRF1_semeval(y_pred, answer_key):
    
    f_out = open(proposed_ans, 'w')
    for i in range(len(y_pred)):
        f_out.write(str(i+1) + "\t" + int_to_label[y_pred[i]] + "\n" )
    f_out.close()
    
    if os.name == 'nt': 
        os.system(perl_exe_path + " " + scorer_perl_script + " " + proposed_ans + " " + answer_key + " > " + scorer_output)
    else: 
        os.system("perl " + " " + scorer_perl_script + " " + proposed_ans + " " + answer_key + " > " + scorer_output)
        
    f_in = open(scorer_output, 'r')
    lines = f_in.readlines()
    f_in.close()
    
    lines = [ l  for l in lines[-30:] if l.strip() != '']
        
    acc = float(lines[-17].strip().split()[-1][:-1]) / 100.0
    PRF1 = lines[-2].strip().split()
    P = float(PRF1[2][:-1]) / 100.0
    R = float(PRF1[5][:-1]) / 100.0
    macro_f1 = float(PRF1[8][:-1]) / 100.0
    
    return (acc, P, R, macro_f1)

# %%
# In[15]:

print("Start training... \n")

# train_x = train_x[:200]
# train_y = train_y[:200]
# train_x_copy = train_x_copy[:200]
# train_y_copy = train_y_copy[:200]
# val_x = val_x[:200]
# val_y = val_y[:200]
# test_x = test_x[:200]
# test_y = test_y[:200]


train_max_acc = 0
train_max_f1 = 0
val_max_acc = 0
val_max_f1 = 0
test_max_acc = 0
test_max_f1 = 0

test_f1_final = 0
test_f1_final_max = 0

es_epoch = 0 

for epoch in range(nb_epoch):
    print("Epoch: ", epoch+1, "/", nb_epoch)
    es_epoch += 1
    if es_epoch > es_epoch_stop:
        print("Early Stopping...") 
        break
    
    index = np.arange(len(train_x))
    np.random.shuffle(index)
    train_x = train_x[index]
    train_x_mask = train_x_mask[index]
    train_y = train_y[index]
    
    # Input lists for fit and predict
    #
    train_input_list = [train_x, train_x_mask]
    train_input_list_copy = [train_x_copy, train_x_mask_copy]
    val_input_list = [val_x, val_x_mask]
    test_input_list = [test_x, test_x_mask]
    #train_input_list = [train_x]
    #train_input_list_copy = [train_x_copy]
    #val_input_list = [val_x]
    #test_input_list = [test_x]

    
    model.fit(train_input_list, train_y, batch_size=batch_size, verbose=1, epochs=1) 
    
    train_y_pred = predict_classes(model.predict(train_input_list_copy, verbose=1))
    val_y_pred = predict_classes(model.predict(val_input_list, verbose=1))
    test_y_pred = predict_classes(model.predict(test_input_list, verbose=1))
    
    train_PRF1 = get_PRF1_semeval(train_y_pred, train_answer_key)
    val_PRF1 = get_PRF1_semeval(val_y_pred, val_answer_key)
    test_PRF1 = get_PRF1_semeval(test_y_pred, test_answer_key)

    train_max_f1 = max(train_max_f1, train_PRF1[3])
    val_max_f1 = max(val_max_f1, val_PRF1[3])
    test_max_f1 = max(test_max_f1, test_PRF1[3])

    train_max_acc = max(train_max_acc, train_PRF1[0])
    val_max_acc = max(val_max_acc, val_PRF1[0])
    test_max_acc = max(test_max_acc, test_PRF1[0])
    
    if val_max_f1 == val_PRF1[3]: 
        test_f1_final = test_PRF1[3]
        test_f1_final_max = max(test_f1_final, test_f1_final_max)
        if save_model : 
            model_file_name = "model.keras"
            model.save('./model/' + model_file_name)
            print("Model saved", model_file_name)
        es_epoch = 0
    
    print("Train Accuracy: %.4f (max: %.4f)" % (train_PRF1[0], train_max_acc))
    print("Val   Accuracy: %.4f (max: %.4f)" % (val_PRF1[0], val_max_acc))
    print("Test  Accuracy: %.4f (max: %.4f)" % (test_PRF1[0], test_max_acc))
    
    print("Train Macro F1 Semeval Official: %.4f (max: %.4f)" % (train_PRF1[3], train_max_f1))
    print("Val   Macro F1 Semeval Official: %.4f (max: %.4f)" % (val_PRF1[3], val_max_f1))
    print("Test  Macro F1 Semeval Official: %.4f (max: %.4f)" % (test_PRF1[3], test_max_f1))
    print("Test P %.4f | R %.4f | macro_F1: %.4f" % test_PRF1[1:] )
    print("Test test_max_f1_final: %.4f (max: %.4f)" % (test_f1_final, test_f1_final_max) )
        
    print()
# Out:
# Start training...
#
# Epoch:  1 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 37s 5ms/step - loss: 5.0217 - acc: 0.1977
# 7208/7208 [==============================] - 5s 738us/step
# 792/792 [==============================] - 1s 716us/step
# 2717/2717 [==============================] - 2s 705us/step
# Model saved model.keras
# Train Accuracy: 0.3430 (max: 0.3430)
# Val   Accuracy: 0.3510 (max: 0.3510)
# Test  Accuracy: 0.3419 (max: 0.3419)
# Train Macro F1 Semeval Official: 0.2704 (max: 0.2704)
# Val   Macro F1 Semeval Official: 0.2704 (max: 0.2704)
# Test  Macro F1 Semeval Official: 0.2630 (max: 0.2630)
# Test P 0.3215 | R 0.3258 | macro_F1: 0.2630
# Test test_max_f1_final: 0.2630 (max: 0.2630)
#
# Epoch:  2 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 4.4629 - acc: 0.3453
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 715us/step
# 2717/2717 [==============================] - 2s 700us/step
# Model saved model.keras
# Train Accuracy: 0.4452 (max: 0.4452)
# Val   Accuracy: 0.4280 (max: 0.4280)
# Test  Accuracy: 0.4428 (max: 0.4428)
# Train Macro F1 Semeval Official: 0.4818 (max: 0.4818)
# Val   Macro F1 Semeval Official: 0.4618 (max: 0.4618)
# Test  Macro F1 Semeval Official: 0.4767 (max: 0.4767)
# Test P 0.4724 | R 0.5319 | macro_F1: 0.4767
# Test test_max_f1_final: 0.4767 (max: 0.4767)
#
# Epoch:  3 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 4.1034 - acc: 0.4462
# 7208/7208 [==============================] - 5s 725us/step
# 792/792 [==============================] - 1s 687us/step
# 2717/2717 [==============================] - 2s 690us/step
# Model saved model.keras
# Train Accuracy: 0.5165 (max: 0.5165)
# Val   Accuracy: 0.4949 (max: 0.4949)
# Test  Accuracy: 0.5083 (max: 0.5083)
# Train Macro F1 Semeval Official: 0.5513 (max: 0.5513)
# Val   Macro F1 Semeval Official: 0.5332 (max: 0.5332)
# Test  Macro F1 Semeval Official: 0.5254 (max: 0.5254)
# Test P 0.5710 | R 0.5773 | macro_F1: 0.5254
# Test test_max_f1_final: 0.5254 (max: 0.5254)
#
# Epoch:  4 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.8464 - acc: 0.5233
# 7208/7208 [==============================] - 5s 705us/step
# 792/792 [==============================] - 1s 688us/step
# 2717/2717 [==============================] - 2s 695us/step
# Model saved model.keras
# Train Accuracy: 0.5536 (max: 0.5536)
# Val   Accuracy: 0.5341 (max: 0.5341)
# Test  Accuracy: 0.5646 (max: 0.5646)
# Train Macro F1 Semeval Official: 0.6088 (max: 0.6088)
# Val   Macro F1 Semeval Official: 0.5892 (max: 0.5892)
# Test  Macro F1 Semeval Official: 0.6026 (max: 0.6026)
# Test P 0.6221 | R 0.6488 | macro_F1: 0.6026
# Test test_max_f1_final: 0.6026 (max: 0.6026)
#
# Epoch:  5 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.6293 - acc: 0.5959
# 7208/7208 [==============================] - 5s 710us/step
# 792/792 [==============================] - 1s 698us/step
# 2717/2717 [==============================] - 2s 688us/step
# Model saved model.keras
# Train Accuracy: 0.6465 (max: 0.6465)
# Val   Accuracy: 0.6275 (max: 0.6275)
# Test  Accuracy: 0.6411 (max: 0.6411)
# Train Macro F1 Semeval Official: 0.6968 (max: 0.6968)
# Val   Macro F1 Semeval Official: 0.6815 (max: 0.6815)
# Test  Macro F1 Semeval Official: 0.6896 (max: 0.6896)
# Test P 0.6638 | R 0.7538 | macro_F1: 0.6896
# Test test_max_f1_final: 0.6896 (max: 0.6896)
#
# Epoch:  6 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.5460 - acc: 0.6211
# 7208/7208 [==============================] - 5s 692us/step
# 792/792 [==============================] - 1s 689us/step
# 2717/2717 [==============================] - 2s 689us/step
# Model saved model.keras
# Train Accuracy: 0.7013 (max: 0.7013)
# Val   Accuracy: 0.6705 (max: 0.6705)
# Test  Accuracy: 0.6897 (max: 0.6897)
# Train Macro F1 Semeval Official: 0.7461 (max: 0.7461)
# Val   Macro F1 Semeval Official: 0.7183 (max: 0.7183)
# Test  Macro F1 Semeval Official: 0.7280 (max: 0.7280)
# Test P 0.7098 | R 0.7604 | macro_F1: 0.7280
# Test test_max_f1_final: 0.7280 (max: 0.7280)
#
# Epoch:  7 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.4475 - acc: 0.6515
# 7208/7208 [==============================] - 5s 696us/step
# 792/792 [==============================] - 1s 686us/step
# 2717/2717 [==============================] - 2s 692us/step
# Model saved model.keras
# Train Accuracy: 0.7293 (max: 0.7293)
# Val   Accuracy: 0.6957 (max: 0.6957)
# Test  Accuracy: 0.6997 (max: 0.6997)
# Train Macro F1 Semeval Official: 0.7723 (max: 0.7723)
# Val   Macro F1 Semeval Official: 0.7361 (max: 0.7361)
# Test  Macro F1 Semeval Official: 0.7387 (max: 0.7387)
# Test P 0.7704 | R 0.7219 | macro_F1: 0.7387
# Test test_max_f1_final: 0.7387 (max: 0.7387)
#
# Epoch:  8 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.3727 - acc: 0.6729
# 7208/7208 [==============================] - 5s 696us/step
# 792/792 [==============================] - 1s 688us/step
# 2717/2717 [==============================] - 2s 693us/step
# Train Accuracy: 0.7372 (max: 0.7372)
# Val   Accuracy: 0.6793 (max: 0.6957)
# Test  Accuracy: 0.7122 (max: 0.7122)
# Train Macro F1 Semeval Official: 0.7786 (max: 0.7786)
# Val   Macro F1 Semeval Official: 0.7171 (max: 0.7361)
# Test  Macro F1 Semeval Official: 0.7524 (max: 0.7524)
# Test P 0.7424 | R 0.7937 | macro_F1: 0.7524
# Test test_max_f1_final: 0.7387 (max: 0.7387)
#
# Epoch:  9 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.3205 - acc: 0.6891
# 7208/7208 [==============================] - 5s 700us/step
# 792/792 [==============================] - 1s 685us/step
# 2717/2717 [==============================] - 2s 692us/step
# Train Accuracy: 0.7335 (max: 0.7372)
# Val   Accuracy: 0.6818 (max: 0.6957)
# Test  Accuracy: 0.7133 (max: 0.7133)
# Train Macro F1 Semeval Official: 0.7915 (max: 0.7915)
# Val   Macro F1 Semeval Official: 0.7345 (max: 0.7361)
# Test  Macro F1 Semeval Official: 0.7655 (max: 0.7655)
# Test P 0.7245 | R 0.8277 | macro_F1: 0.7655
# Test test_max_f1_final: 0.7387 (max: 0.7387)
#
# Epoch:  10 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.2617 - acc: 0.7052
# 7208/7208 [==============================] - 5s 694us/step
# 792/792 [==============================] - 1s 696us/step
# 2717/2717 [==============================] - 2s 694us/step
# Model saved model.keras
# Train Accuracy: 0.7852 (max: 0.7852)
# Val   Accuracy: 0.7513 (max: 0.7513)
# Test  Accuracy: 0.7457 (max: 0.7457)
# Train Macro F1 Semeval Official: 0.8291 (max: 0.8291)
# Val   Macro F1 Semeval Official: 0.7956 (max: 0.7956)
# Test  Macro F1 Semeval Official: 0.7896 (max: 0.7896)
# Test P 0.7819 | R 0.8081 | macro_F1: 0.7896
# Test test_max_f1_final: 0.7896 (max: 0.7896)
#
# Epoch:  11 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.2193 - acc: 0.7146
# 7208/7208 [==============================] - 5s 694us/step
# 792/792 [==============================] - 1s 700us/step
# 2717/2717 [==============================] - 2s 694us/step
# Train Accuracy: 0.7973 (max: 0.7973)
# Val   Accuracy: 0.7475 (max: 0.7513)
# Test  Accuracy: 0.7600 (max: 0.7600)
# Train Macro F1 Semeval Official: 0.8384 (max: 0.8384)
# Val   Macro F1 Semeval Official: 0.7922 (max: 0.7956)
# Test  Macro F1 Semeval Official: 0.7995 (max: 0.7995)
# Test P 0.7749 | R 0.8347 | macro_F1: 0.7995
# Test test_max_f1_final: 0.7896 (max: 0.7896)
#
# Epoch:  12 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.1884 - acc: 0.7292
# 7208/7208 [==============================] - 5s 697us/step
# 792/792 [==============================] - 1s 701us/step
# 2717/2717 [==============================] - 2s 696us/step
# Model saved model.keras
# Train Accuracy: 0.8083 (max: 0.8083)
# Val   Accuracy: 0.7525 (max: 0.7525)
# Test  Accuracy: 0.7619 (max: 0.7619)
# Train Macro F1 Semeval Official: 0.8504 (max: 0.8504)
# Val   Macro F1 Semeval Official: 0.7972 (max: 0.7972)
# Test  Macro F1 Semeval Official: 0.8013 (max: 0.8013)
# Test P 0.7819 | R 0.8269 | macro_F1: 0.8013
# Test test_max_f1_final: 0.8013 (max: 0.8013)
#
# Epoch:  13 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.1513 - acc: 0.7356
# 7208/7208 [==============================] - 5s 715us/step
# 792/792 [==============================] - 1s 705us/step
# 2717/2717 [==============================] - 2s 695us/step
# Model saved model.keras
# Train Accuracy: 0.8094 (max: 0.8094)
# Val   Accuracy: 0.7702 (max: 0.7702)
# Test  Accuracy: 0.7597 (max: 0.7619)
# Train Macro F1 Semeval Official: 0.8491 (max: 0.8504)
# Val   Macro F1 Semeval Official: 0.8062 (max: 0.8062)
# Test  Macro F1 Semeval Official: 0.7985 (max: 0.8013)
# Test P 0.7763 | R 0.8305 | macro_F1: 0.7985
# Test test_max_f1_final: 0.7985 (max: 0.8013)
#
# Epoch:  14 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.1145 - acc: 0.7432
# 7208/7208 [==============================] - 5s 698us/step
# 792/792 [==============================] - 1s 685us/step
# 2717/2717 [==============================] - 2s 692us/step
# Train Accuracy: 0.8123 (max: 0.8123)
# Val   Accuracy: 0.7576 (max: 0.7702)
# Test  Accuracy: 0.7626 (max: 0.7626)
# Train Macro F1 Semeval Official: 0.8565 (max: 0.8565)
# Val   Macro F1 Semeval Official: 0.8000 (max: 0.8062)
# Test  Macro F1 Semeval Official: 0.8093 (max: 0.8093)
# Test P 0.7651 | R 0.8629 | macro_F1: 0.8093
# Test test_max_f1_final: 0.7985 (max: 0.8013)
#
# Epoch:  15 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.1001 - acc: 0.7489
# 7208/7208 [==============================] - 5s 705us/step
# 792/792 [==============================] - 1s 701us/step
# 2717/2717 [==============================] - 2s 699us/step
# Train Accuracy: 0.8158 (max: 0.8158)
# Val   Accuracy: 0.7487 (max: 0.7702)
# Test  Accuracy: 0.7497 (max: 0.7626)
# Train Macro F1 Semeval Official: 0.8534 (max: 0.8565)
# Val   Macro F1 Semeval Official: 0.7890 (max: 0.8062)
# Test  Macro F1 Semeval Official: 0.7917 (max: 0.8093)
# Test P 0.7636 | R 0.8397 | macro_F1: 0.7917
# Test test_max_f1_final: 0.7985 (max: 0.8013)
#
# Epoch:  16 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.0636 - acc: 0.7593
# 7208/7208 [==============================] - 5s 710us/step
# 792/792 [==============================] - 1s 695us/step
# 2717/2717 [==============================] - 2s 700us/step
# Train Accuracy: 0.8327 (max: 0.8327)
# Val   Accuracy: 0.7626 (max: 0.7702)
# Test  Accuracy: 0.7608 (max: 0.7626)
# Train Macro F1 Semeval Official: 0.8744 (max: 0.8744)
# Val   Macro F1 Semeval Official: 0.8026 (max: 0.8062)
# Test  Macro F1 Semeval Official: 0.8047 (max: 0.8093)
# Test P 0.7764 | R 0.8431 | macro_F1: 0.8047
# Test test_max_f1_final: 0.7985 (max: 0.8013)
#
# Epoch:  17 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.0182 - acc: 0.7758
# 7208/7208 [==============================] - 5s 704us/step
# 792/792 [==============================] - 1s 703us/step
# 2717/2717 [==============================] - 2s 695us/step
# Train Accuracy: 0.8130 (max: 0.8327)
# Val   Accuracy: 0.7487 (max: 0.7702)
# Test  Accuracy: 0.7449 (max: 0.7626)
# Train Macro F1 Semeval Official: 0.8627 (max: 0.8744)
# Val   Macro F1 Semeval Official: 0.8000 (max: 0.8062)
# Test  Macro F1 Semeval Official: 0.7933 (max: 0.8093)
# Test P 0.7494 | R 0.8553 | macro_F1: 0.7933
# Test test_max_f1_final: 0.7985 (max: 0.8013)
#
# Epoch:  18 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 3.0091 - acc: 0.7776
# 7208/7208 [==============================] - 5s 705us/step
# 792/792 [==============================] - 1s 689us/step
# 2717/2717 [==============================] - 2s 698us/step
# Model saved model.keras
# Train Accuracy: 0.8538 (max: 0.8538)
# Val   Accuracy: 0.7778 (max: 0.7778)
# Test  Accuracy: 0.7766 (max: 0.7766)
# Train Macro F1 Semeval Official: 0.8902 (max: 0.8902)
# Val   Macro F1 Semeval Official: 0.8186 (max: 0.8186)
# Test  Macro F1 Semeval Official: 0.8170 (max: 0.8170)
# Test P 0.7953 | R 0.8445 | macro_F1: 0.8170
# Test test_max_f1_final: 0.8170 (max: 0.8170)
#
# Epoch:  19 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.9767 - acc: 0.7791
# 7208/7208 [==============================] - 5s 703us/step
# 792/792 [==============================] - 1s 706us/step
# 2717/2717 [==============================] - 2s 702us/step
# Train Accuracy: 0.8346 (max: 0.8538)
# Val   Accuracy: 0.7639 (max: 0.7778)
# Test  Accuracy: 0.7644 (max: 0.7766)
# Train Macro F1 Semeval Official: 0.8812 (max: 0.8902)
# Val   Macro F1 Semeval Official: 0.8090 (max: 0.8186)
# Test  Macro F1 Semeval Official: 0.8130 (max: 0.8170)
# Test P 0.7723 | R 0.8634 | macro_F1: 0.8130
# Test test_max_f1_final: 0.8170 (max: 0.8170)
#
# Epoch:  20 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.9465 - acc: 0.7925
# 7208/7208 [==============================] - 5s 701us/step
# 792/792 [==============================] - 1s 713us/step
# 2717/2717 [==============================] - 2s 698us/step
# Train Accuracy: 0.8645 (max: 0.8645)
# Val   Accuracy: 0.7702 (max: 0.7778)
# Test  Accuracy: 0.7795 (max: 0.7795)
# Train Macro F1 Semeval Official: 0.8987 (max: 0.8987)
# Val   Macro F1 Semeval Official: 0.8041 (max: 0.8186)
# Test  Macro F1 Semeval Official: 0.8199 (max: 0.8199)
# Test P 0.8005 | R 0.8491 | macro_F1: 0.8199
# Test test_max_f1_final: 0.8170 (max: 0.8170)
#
# Epoch:  21 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.9270 - acc: 0.7912
# 7208/7208 [==============================] - 5s 700us/step
# 792/792 [==============================] - 1s 705us/step
# 2717/2717 [==============================] - 2s 704us/step
# Model saved model.keras
# Train Accuracy: 0.8726 (max: 0.8726)
# Val   Accuracy: 0.7866 (max: 0.7866)
# Test  Accuracy: 0.7803 (max: 0.7803)
# Train Macro F1 Semeval Official: 0.9030 (max: 0.9030)
# Val   Macro F1 Semeval Official: 0.8260 (max: 0.8260)
# Test  Macro F1 Semeval Official: 0.8203 (max: 0.8203)
# Test P 0.7982 | R 0.8502 | macro_F1: 0.8203
# Test test_max_f1_final: 0.8203 (max: 0.8203)
#
# Epoch:  22 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8990 - acc: 0.8016
# 7208/7208 [==============================] - 5s 701us/step
# 792/792 [==============================] - 1s 711us/step
# 2717/2717 [==============================] - 2s 696us/step
# Model saved model.keras
# Train Accuracy: 0.8782 (max: 0.8782)
# Val   Accuracy: 0.7866 (max: 0.7866)
# Test  Accuracy: 0.7825 (max: 0.7825)
# Train Macro F1 Semeval Official: 0.9100 (max: 0.9100)
# Val   Macro F1 Semeval Official: 0.8317 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8240 (max: 0.8240)
# Test P 0.8040 | R 0.8526 | macro_F1: 0.8240
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  23 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8946 - acc: 0.8022
# 7208/7208 [==============================] - 5s 704us/step
# 792/792 [==============================] - 1s 690us/step
# 2717/2717 [==============================] - 2s 697us/step
# Train Accuracy: 0.8725 (max: 0.8782)
# Val   Accuracy: 0.7778 (max: 0.7866)
# Test  Accuracy: 0.7759 (max: 0.7825)
# Train Macro F1 Semeval Official: 0.9086 (max: 0.9100)
# Val   Macro F1 Semeval Official: 0.8203 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8212 (max: 0.8240)
# Test P 0.7838 | R 0.8649 | macro_F1: 0.8212
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  24 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8708 - acc: 0.8072
# 7208/7208 [==============================] - 5s 703us/step
# 792/792 [==============================] - 1s 705us/step
# 2717/2717 [==============================] - 2s 704us/step
# Train Accuracy: 0.8586 (max: 0.8782)
# Val   Accuracy: 0.7639 (max: 0.7866)
# Test  Accuracy: 0.7707 (max: 0.7825)
# Train Macro F1 Semeval Official: 0.9010 (max: 0.9100)
# Val   Macro F1 Semeval Official: 0.8068 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8166 (max: 0.8240)
# Test P 0.7755 | R 0.8686 | macro_F1: 0.8166
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  25 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8455 - acc: 0.8190
# 7208/7208 [==============================] - 5s 697us/step
# 792/792 [==============================] - 1s 701us/step
# 2717/2717 [==============================] - 2s 695us/step
# Train Accuracy: 0.8914 (max: 0.8914)
# Val   Accuracy: 0.7816 (max: 0.7866)
# Test  Accuracy: 0.7814 (max: 0.7825)
# Train Macro F1 Semeval Official: 0.9175 (max: 0.9175)
# Val   Macro F1 Semeval Official: 0.8176 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8236 (max: 0.8240)
# Test P 0.7964 | R 0.8592 | macro_F1: 0.8236
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  26 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8152 - acc: 0.8192
# 7208/7208 [==============================] - 5s 702us/step
# 792/792 [==============================] - 1s 693us/step
# 2717/2717 [==============================] - 2s 701us/step
# Train Accuracy: 0.8753 (max: 0.8914)
# Val   Accuracy: 0.7816 (max: 0.7866)
# Test  Accuracy: 0.7729 (max: 0.7825)
# Train Macro F1 Semeval Official: 0.9125 (max: 0.9175)
# Val   Macro F1 Semeval Official: 0.8245 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8235 (max: 0.8240)
# Test P 0.7857 | R 0.8697 | macro_F1: 0.8235
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  27 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.8114 - acc: 0.8278
# 7208/7208 [==============================] - 5s 712us/step
# 792/792 [==============================] - 1s 699us/step
# 2717/2717 [==============================] - 2s 702us/step
# Train Accuracy: 0.9112 (max: 0.9112)
# Val   Accuracy: 0.7942 (max: 0.7942)
# Test  Accuracy: 0.7840 (max: 0.7840)
# Train Macro F1 Semeval Official: 0.9363 (max: 0.9363)
# Val   Macro F1 Semeval Official: 0.8316 (max: 0.8317)
# Test  Macro F1 Semeval Official: 0.8296 (max: 0.8296)
# Test P 0.8119 | R 0.8532 | macro_F1: 0.8296
# Test test_max_f1_final: 0.8240 (max: 0.8240)
#
# Epoch:  28 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7987 - acc: 0.8248
# 7208/7208 [==============================] - 5s 708us/step
# 792/792 [==============================] - 1s 703us/step
# 2717/2717 [==============================] - 2s 697us/step
# Model saved model.keras
# Train Accuracy: 0.9022 (max: 0.9112)
# Val   Accuracy: 0.7955 (max: 0.7955)
# Test  Accuracy: 0.7946 (max: 0.7946)
# Train Macro F1 Semeval Official: 0.9316 (max: 0.9363)
# Val   Macro F1 Semeval Official: 0.8357 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8389 (max: 0.8389)
# Test P 0.8090 | R 0.8732 | macro_F1: 0.8389
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  29 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7804 - acc: 0.8276
# 7208/7208 [==============================] - 5s 717us/step
# 792/792 [==============================] - 1s 699us/step
# 2717/2717 [==============================] - 2s 696us/step
# Train Accuracy: 0.9069 (max: 0.9112)
# Val   Accuracy: 0.7917 (max: 0.7955)
# Test  Accuracy: 0.7814 (max: 0.7946)
# Train Macro F1 Semeval Official: 0.9315 (max: 0.9363)
# Val   Macro F1 Semeval Official: 0.8312 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8270 (max: 0.8389)
# Test P 0.8086 | R 0.8487 | macro_F1: 0.8270
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  30 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7585 - acc: 0.8285
# 7208/7208 [==============================] - 5s 708us/step
# 792/792 [==============================] - 1s 700us/step
# 2717/2717 [==============================] - 2s 695us/step
# Train Accuracy: 0.9108 (max: 0.9112)
# Val   Accuracy: 0.7854 (max: 0.7955)
# Test  Accuracy: 0.7696 (max: 0.7946)
# Train Macro F1 Semeval Official: 0.9336 (max: 0.9363)
# Val   Macro F1 Semeval Official: 0.8279 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8134 (max: 0.8389)
# Test P 0.8384 | R 0.8013 | macro_F1: 0.8134
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  31 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7432 - acc: 0.8381
# 7208/7208 [==============================] - 5s 707us/step
# 792/792 [==============================] - 1s 706us/step
# 2717/2717 [==============================] - 2s 699us/step
# Train Accuracy: 0.9123 (max: 0.9123)
# Val   Accuracy: 0.7841 (max: 0.7955)
# Test  Accuracy: 0.7913 (max: 0.7946)
# Train Macro F1 Semeval Official: 0.9364 (max: 0.9364)
# Val   Macro F1 Semeval Official: 0.8192 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8326 (max: 0.8389)
# Test P 0.8108 | R 0.8641 | macro_F1: 0.8326
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  32 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7196 - acc: 0.8467
# 7208/7208 [==============================] - 5s 705us/step
# 792/792 [==============================] - 1s 695us/step
# 2717/2717 [==============================] - 2s 699us/step
# Train Accuracy: 0.9197 (max: 0.9197)
# Val   Accuracy: 0.7980 (max: 0.7980)
# Test  Accuracy: 0.8009 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9395 (max: 0.9395)
# Val   Macro F1 Semeval Official: 0.8349 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8374 (max: 0.8389)
# Test P 0.8080 | R 0.8727 | macro_F1: 0.8374
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  33 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.7076 - acc: 0.8453
# 7208/7208 [==============================] - 5s 700us/step
# 792/792 [==============================] - 1s 693us/step
# 2717/2717 [==============================] - 2s 698us/step
# Train Accuracy: 0.9036 (max: 0.9197)
# Val   Accuracy: 0.7803 (max: 0.7980)
# Test  Accuracy: 0.7817 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9316 (max: 0.9395)
# Val   Macro F1 Semeval Official: 0.8203 (max: 0.8357)
# Test  Macro F1 Semeval Official: 0.8245 (max: 0.8389)
# Test P 0.7980 | R 0.8623 | macro_F1: 0.8245
# Test test_max_f1_final: 0.8389 (max: 0.8389)
#
# Epoch:  34 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6737 - acc: 0.8570
# 7208/7208 [==============================] - 5s 701us/step
# 792/792 [==============================] - 1s 691us/step
# 2717/2717 [==============================] - 2s 698us/step
# Model saved model.keras
# Train Accuracy: 0.9272 (max: 0.9272)
# Val   Accuracy: 0.8018 (max: 0.8018)
# Test  Accuracy: 0.8009 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9499 (max: 0.9499)
# Val   Macro F1 Semeval Official: 0.8397 (max: 0.8397)
# Test  Macro F1 Semeval Official: 0.8409 (max: 0.8409)
# Test P 0.8072 | R 0.8788 | macro_F1: 0.8409
# Test test_max_f1_final: 0.8409 (max: 0.8409)
#
# Epoch:  35 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6696 - acc: 0.8579
# 7208/7208 [==============================] - 5s 702us/step
# 792/792 [==============================] - 1s 695us/step
# 2717/2717 [==============================] - 2s 701us/step
# Train Accuracy: 0.9226 (max: 0.9272)
# Val   Accuracy: 0.7904 (max: 0.8018)
# Test  Accuracy: 0.7939 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9473 (max: 0.9499)
# Val   Macro F1 Semeval Official: 0.8279 (max: 0.8397)
# Test  Macro F1 Semeval Official: 0.8379 (max: 0.8409)
# Test P 0.8031 | R 0.8790 | macro_F1: 0.8379
# Test test_max_f1_final: 0.8409 (max: 0.8409)
#
# Epoch:  36 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6541 - acc: 0.8572
# 7208/7208 [==============================] - 5s 696us/step
# 792/792 [==============================] - 1s 699us/step
# 2717/2717 [==============================] - 2s 699us/step
# Model saved model.keras
# Train Accuracy: 0.9463 (max: 0.9463)
# Val   Accuracy: 0.8081 (max: 0.8081)
# Test  Accuracy: 0.7935 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9587 (max: 0.9587)
# Val   Macro F1 Semeval Official: 0.8466 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8352 (max: 0.8409)
# Test P 0.8262 | R 0.8492 | macro_F1: 0.8352
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  37 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6390 - acc: 0.8649
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 694us/step
# 2717/2717 [==============================] - 2s 696us/step
# Train Accuracy: 0.8986 (max: 0.9463)
# Val   Accuracy: 0.7677 (max: 0.8081)
# Test  Accuracy: 0.7736 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9273 (max: 0.9587)
# Val   Macro F1 Semeval Official: 0.8101 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8215 (max: 0.8409)
# Test P 0.7839 | R 0.8707 | macro_F1: 0.8215
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  38 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6286 - acc: 0.8614
# 7208/7208 [==============================] - 5s 712us/step
# 792/792 [==============================] - 1s 703us/step
# 2717/2717 [==============================] - 2s 702us/step
# Train Accuracy: 0.9377 (max: 0.9463)
# Val   Accuracy: 0.7828 (max: 0.8081)
# Test  Accuracy: 0.7898 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9545 (max: 0.9587)
# Val   Macro F1 Semeval Official: 0.8165 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8306 (max: 0.8409)
# Test P 0.8078 | R 0.8598 | macro_F1: 0.8306
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  39 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.6229 - acc: 0.8672
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 689us/step
# 2717/2717 [==============================] - 2s 692us/step
# Train Accuracy: 0.9408 (max: 0.9463)
# Val   Accuracy: 0.7967 (max: 0.8081)
# Test  Accuracy: 0.7972 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9587 (max: 0.9587)
# Val   Macro F1 Semeval Official: 0.8288 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8343 (max: 0.8409)
# Test P 0.8136 | R 0.8632 | macro_F1: 0.8343
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  40 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5836 - acc: 0.8789
# 7208/7208 [==============================] - 5s 702us/step
# 792/792 [==============================] - 1s 684us/step
# 2717/2717 [==============================] - 2s 701us/step
# Train Accuracy: 0.9538 (max: 0.9538)
# Val   Accuracy: 0.7955 (max: 0.8081)
# Test  Accuracy: 0.8001 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9675 (max: 0.9675)
# Val   Macro F1 Semeval Official: 0.8374 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8396 (max: 0.8409)
# Test P 0.8219 | R 0.8613 | macro_F1: 0.8396
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  41 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5900 - acc: 0.8758
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 706us/step
# 2717/2717 [==============================] - 2s 695us/step
# Train Accuracy: 0.9605 (max: 0.9605)
# Val   Accuracy: 0.7992 (max: 0.8081)
# Test  Accuracy: 0.7983 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9707 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8354 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8421 (max: 0.8421)
# Test P 0.8368 | R 0.8492 | macro_F1: 0.8421
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  42 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5829 - acc: 0.8742
# 7208/7208 [==============================] - 5s 702us/step
# 792/792 [==============================] - 1s 699us/step
# 2717/2717 [==============================] - 2s 693us/step
# Train Accuracy: 0.9444 (max: 0.9605)
# Val   Accuracy: 0.7828 (max: 0.8081)
# Test  Accuracy: 0.7950 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9607 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8153 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8380 (max: 0.8421)
# Test P 0.8158 | R 0.8674 | macro_F1: 0.8380
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  43 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5712 - acc: 0.8728
# 7208/7208 [==============================] - 5s 708us/step
# 792/792 [==============================] - 1s 722us/step
# 2717/2717 [==============================] - 2s 701us/step
# Train Accuracy: 0.9566 (max: 0.9605)
# Val   Accuracy: 0.7955 (max: 0.8081)
# Test  Accuracy: 0.7935 (max: 0.8009)
# Train Macro F1 Semeval Official: 0.9693 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8328 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8358 (max: 0.8421)
# Test P 0.8181 | R 0.8585 | macro_F1: 0.8358
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  44 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5415 - acc: 0.8862
# 7208/7208 [==============================] - 5s 700us/step
# 792/792 [==============================] - 1s 694us/step
# 2717/2717 [==============================] - 2s 698us/step
# Train Accuracy: 0.9478 (max: 0.9605)
# Val   Accuracy: 0.7992 (max: 0.8081)
# Test  Accuracy: 0.8038 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9640 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8334 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8431 (max: 0.8431)
# Test P 0.8137 | R 0.8797 | macro_F1: 0.8431
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  45 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5324 - acc: 0.8901
# 7208/7208 [==============================] - 5s 706us/step
# 792/792 [==============================] - 1s 708us/step
# 2717/2717 [==============================] - 2s 690us/step
# Train Accuracy: 0.9519 (max: 0.9605)
# Val   Accuracy: 0.7891 (max: 0.8081)
# Test  Accuracy: 0.7965 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9679 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8293 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8391 (max: 0.8431)
# Test P 0.8037 | R 0.8781 | macro_F1: 0.8391
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  46 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5256 - acc: 0.8822
# 7208/7208 [==============================] - 5s 712us/step
# 792/792 [==============================] - 1s 722us/step
# 2717/2717 [==============================] - 2s 701us/step
# Train Accuracy: 0.9526 (max: 0.9605)
# Val   Accuracy: 0.7929 (max: 0.8081)
# Test  Accuracy: 0.7976 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9648 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8354 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8361 (max: 0.8431)
# Test P 0.8035 | R 0.8782 | macro_F1: 0.8361
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  47 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5144 - acc: 0.8868
# 7208/7208 [==============================] - 5s 698us/step
# 792/792 [==============================] - 1s 705us/step
# 2717/2717 [==============================] - 2s 693us/step
# Train Accuracy: 0.9520 (max: 0.9605)
# Val   Accuracy: 0.8018 (max: 0.8081)
# Test  Accuracy: 0.7884 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9655 (max: 0.9707)
# Val   Macro F1 Semeval Official: 0.8392 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8270 (max: 0.8431)
# Test P 0.8002 | R 0.8615 | macro_F1: 0.8270
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  48 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.5002 - acc: 0.8910
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 703us/step
# 2717/2717 [==============================] - 2s 696us/step
# Train Accuracy: 0.9711 (max: 0.9711)
# Val   Accuracy: 0.8043 (max: 0.8081)
# Test  Accuracy: 0.7957 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9780 (max: 0.9780)
# Val   Macro F1 Semeval Official: 0.8376 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8365 (max: 0.8431)
# Test P 0.8187 | R 0.8580 | macro_F1: 0.8365
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  49 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4934 - acc: 0.8925
# 7208/7208 [==============================] - 5s 698us/step
# 792/792 [==============================] - 1s 701us/step
# 2717/2717 [==============================] - 2s 691us/step
# Train Accuracy: 0.9502 (max: 0.9711)
# Val   Accuracy: 0.7828 (max: 0.8081)
# Test  Accuracy: 0.7858 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9666 (max: 0.9780)
# Val   Macro F1 Semeval Official: 0.8232 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8280 (max: 0.8431)
# Test P 0.7945 | R 0.8686 | macro_F1: 0.8280
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  50 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4825 - acc: 0.8905
# 7208/7208 [==============================] - 5s 694us/step
# 792/792 [==============================] - 1s 693us/step
# 2717/2717 [==============================] - 2s 689us/step
# Train Accuracy: 0.9575 (max: 0.9711)
# Val   Accuracy: 0.7992 (max: 0.8081)
# Test  Accuracy: 0.7898 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9706 (max: 0.9780)
# Val   Macro F1 Semeval Official: 0.8370 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8320 (max: 0.8431)
# Test P 0.7987 | R 0.8722 | macro_F1: 0.8320
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  51 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4676 - acc: 0.8973
# 7208/7208 [==============================] - 5s 694us/step
# 792/792 [==============================] - 1s 695us/step
# 2717/2717 [==============================] - 2s 694us/step
# Train Accuracy: 0.9710 (max: 0.9711)
# Val   Accuracy: 0.7967 (max: 0.8081)
# Test  Accuracy: 0.7869 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9795 (max: 0.9795)
# Val   Macro F1 Semeval Official: 0.8295 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8278 (max: 0.8431)
# Test P 0.8061 | R 0.8551 | macro_F1: 0.8278
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  52 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4533 - acc: 0.9032
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 696us/step
# 2717/2717 [==============================] - 2s 690us/step
# Train Accuracy: 0.9741 (max: 0.9741)
# Val   Accuracy: 0.7929 (max: 0.8081)
# Test  Accuracy: 0.7880 (max: 0.8038)
# Train Macro F1 Semeval Official: 0.9801 (max: 0.9801)
# Val   Macro F1 Semeval Official: 0.8280 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8299 (max: 0.8431)
# Test P 0.8112 | R 0.8541 | macro_F1: 0.8299
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  53 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4542 - acc: 0.9018
# 7208/7208 [==============================] - 5s 699us/step
# 792/792 [==============================] - 1s 704us/step
# 2717/2717 [==============================] - 2s 694us/step
# Train Accuracy: 0.9764 (max: 0.9764)
# Val   Accuracy: 0.8018 (max: 0.8081)
# Test  Accuracy: 0.8053 (max: 0.8053)
# Train Macro F1 Semeval Official: 0.9833 (max: 0.9833)
# Val   Macro F1 Semeval Official: 0.8382 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8449 (max: 0.8449)
# Test P 0.8184 | R 0.8744 | macro_F1: 0.8449
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  54 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4398 - acc: 0.9023
# 7208/7208 [==============================] - 5s 698us/step
# 792/792 [==============================] - 1s 705us/step
# 2717/2717 [==============================] - 2s 695us/step
# Train Accuracy: 0.9581 (max: 0.9764)
# Val   Accuracy: 0.7891 (max: 0.8081)
# Test  Accuracy: 0.7858 (max: 0.8053)
# Train Macro F1 Semeval Official: 0.9708 (max: 0.9833)
# Val   Macro F1 Semeval Official: 0.8247 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8304 (max: 0.8449)
# Test P 0.8039 | R 0.8646 | macro_F1: 0.8304
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  55 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4231 - acc: 0.9061
# 7208/7208 [==============================] - 5s 700us/step
# 792/792 [==============================] - 1s 701us/step
# 2717/2717 [==============================] - 2s 697us/step
# Train Accuracy: 0.9727 (max: 0.9764)
# Val   Accuracy: 0.8081 (max: 0.8081)
# Test  Accuracy: 0.7965 (max: 0.8053)
# Train Macro F1 Semeval Official: 0.9808 (max: 0.9833)
# Val   Macro F1 Semeval Official: 0.8441 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8382 (max: 0.8449)
# Test P 0.8111 | R 0.8695 | macro_F1: 0.8382
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  56 / 256
# Epoch 1/1
# 7208/7208 [==============================] - 21s 3ms/step - loss: 2.4150 - acc: 0.9064
# 7208/7208 [==============================] - 5s 697us/step
# 792/792 [==============================] - 1s 700us/step
# 2717/2717 [==============================] - 2s 694us/step
# Train Accuracy: 0.9825 (max: 0.9825)
# Val   Accuracy: 0.8030 (max: 0.8081)
# Test  Accuracy: 0.7968 (max: 0.8053)
# Train Macro F1 Semeval Official: 0.9872 (max: 0.9872)
# Val   Macro F1 Semeval Official: 0.8374 (max: 0.8466)
# Test  Macro F1 Semeval Official: 0.8362 (max: 0.8449)
# Test P 0.8213 | R 0.8563 | macro_F1: 0.8362
# Test test_max_f1_final: 0.8352 (max: 0.8409)
#
# Epoch:  57 / 256
# Early Stopping...

# %%
# # In[ ]:

# from keras_visualize_activations_master import read_activations

# def create_heatmap_file(model, layer_name, out_file_path="./model/test_heatmap.txt", batch_size=500): 
    
#     print("Loading data...")
    
#     data_npy_path = './data/data_all.npy'
#     train_file = "./files/train_attn_sp.txt"
#     val_file = "./files/val_attn_sp.txt"
#     test_file = "./files/test_attn_sp.txt"

#     train_set, val_set, test_set, embedding, label_to_int, int_to_label = np.load(data_npy_path)
#     train_x, train_y = train_set
#     val_x, val_y = val_set
#     test_x, test_y = test_set
#     train_x_copy = train_x
#     train_y_copy = train_y
#     max_sentence_len = train_x.shape[1]
#     n_out = len(label_to_int)
    
#     l2_val = 0.00001
#     embeddings_reg = regularizers.l2(l2_val)
#     kernel_reg = regularizers.l2(l2_val)
#     recurrent_reg = regularizers.l2(l2_val)

#     # # Getting activations 
    
#     print("Getting activations...")

#     def get_activation(data, model, batch_size=100):
#         ret = None
#         for i in range(0, data.shape[0], batch_size): 
#             start = i 
#             endd = min(i+batch_size, data.shape[0]) 
#             act = read_activations.get_activations(model, data[start:endd], layer_name=layer_name, print_shape_only=True)
#             if i == 0: 
#                 ret = act[0] 
#             else: 
#                 ret = np.concatenate((ret, act[0]))
#         return ret 

#     test_act = get_activation(test_x, model, batch_size)
#     print("Activatons shape test_act.shape", test_act.shape)

#     def softmax(x):
#         e_x = np.exp(x - np.max(x))
#         return e_x / e_x.sum(axis=0)    
    
#     print("Creating heatmap file...")
    
#     def write_heatmap_file(act, in_file_name, out_file_path):
#         f = open(in_file_name, 'r')
#         lines = f.readlines()
#         f.close()

#         num_labels = [ l.strip().split()[:2] for l in lines ]
#         lines = [ l.strip().split()[2:] for l in lines ]

#         print("act", act.shape)
#         act = np.sum(act, axis=-2)
#         print("act", act.shape)

#         for j in range(act.shape[0]):
#             act[j] = softmax(act[j])
            
#         print("np.sum(act[0])", np.sum(act[0]))

#         f = open(out_file_path, "w")

#         for i in range(len(lines)): 
#             f.write(str(num_labels[i][1]) + "\n")
#             for j in range(len(lines[i])):
#                 tmp = ( "%.6f " % (act[i][j]*100.0)  )
#                 f.write(lines[i][j] + "\t" + tmp + "\n")
#             f.write("\n")

#         f.close()
        
#         print("Created", out_file_path)
    
#     write_heatmap_file(test_act, test_file, out_file_path)
#     return test_act
    

# model_keras_path = "./model/model.keras"
# model = load_model(model_keras_path, custom_objects={"tf": tf, "MaskMaxPoolingLayer": MaskMaxPoolingLayer})
# model.summary()

# layer_name = "attn_softmax"
# act = create_heatmap_file(model, layer_name, out_file_path="./model/test_heatmap.txt")
